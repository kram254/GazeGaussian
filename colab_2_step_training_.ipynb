# %% [markdown]
# # GazeGaussian Enhanced (DiT) - 2-Step Training
#
# ## Overview
# This notebook trains the enhanced GazeGaussian model with:
# 1. **DiT Neural Renderer** (replacing U-Net)
# 2. **VAE Integration**
# 3. **Orthogonality Regularization**
#
# ## Training Process
# - **Step 1**: Train MeshHead (~10 epochs, ~2-3 hours)
# - **Step 2**: Train GazeGaussian with DiT (~30 epochs, ~8-12 hours)
#
# ## Requirements
# - GPU: A100 (40GB recommended) or V100 (32GB minimum)
# - Dataset: ETH-XGaze training set in Google Drive
# - Time: ~12-15 hours total

# %%
# !nvidia-smi
# Out:
# Thu Oct 30 14:33:52 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !rm -rf GazeGaussian
# !git clone --recursive https://github.com/kram254/GazeGaussian.git
# %cd GazeGaussian
# !git submodule update --init --recursive
# Out:
# /content
# Cloning into 'GazeGaussian'...
# remote: Enumerating objects: 1682, done.
# remote: Counting objects: 100% (1682/1682), done.
# remote: Compressing objects: 100% (724/724), done.
# remote: Total 1682 (delta 970), reused 1654 (delta 942), pack-reused 0 (from 0)
# Receiving objects: 100% (1682/1682), 18.80 MiB | 21.00 MiB/s, done.
# Resolving deltas: 100% (970/970), done.
# /content/GazeGaussian

# %% [markdown]
# ## 2. Install Dependencies

# %%
# !pip install --upgrade pip setuptools wheel ninja
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (75.2.0)
# Collecting setuptools
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)
# Collecting ninja
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.3 MB/s eta 0:00:00
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.4 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 14.6 MB/s eta 0:00:00
# Installing collected packages: setuptools, pip, ninja
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed ninja-1.13.0 pip-25.3 setuptools-80.9.0

# %%
# !pip install opencv-python h5py tqdm scipy scikit-image lpips kornia tensorboardX einops trimesh plyfile
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (3.15.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (0.25.2)
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Collecting kornia
#   Downloading kornia-0.8.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Collecting trimesh
#   Downloading trimesh-4.9.0-py3-none-any.whl.metadata (18 kB)
# Collecting plyfile
#   Downloading plyfile-1.1.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.23.0+cu126)
# Collecting kornia_rs>=0.1.9 (from kornia)
#   Downloading kornia_rs-0.1.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (5.29.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
# Downloading kornia-0.8.1-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.8 MB/s  0:00:00
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Downloading trimesh-4.9.0-py3-none-any.whl (736 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.5/736.5 kB 47.7 MB/s  0:00:00
# Downloading plyfile-1.1.3-py3-none-any.whl (36 kB)
# Downloading kornia_rs-0.1.9-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 119.4 MB/s  0:00:00
# Installing collected packages: trimesh, tensorboardX, plyfile, kornia_rs, kornia, lpips
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [lpips]
# Successfully installed kornia-0.8.1 kornia_rs-0.1.9 lpips-0.1.4 plyfile-1.1.3 tensorboardX-2.6.4 trimesh-4.9.0

# %%
# !pip install --force-reinstall torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu121/torch-2.5.1%2Bcu121-cp312-cp312-linux_x86_64.whl (780.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 MB 20.3 MB/s  0:00:18
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu121/torchvision-0.20.1%2Bcu121-cp312-cp312-linux_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 148.2 MB/s  0:00:00
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu121/torchaudio-2.5.1%2Bcu121-cp312-cp312-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 132.4 MB/s  0:00:00
# Collecting filelock (from torch)
#   Downloading https://download.pytorch.org/whl/filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Downloading https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting networkx (from torch)
#   Downloading https://download.pytorch.org/whl/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading https://download.pytorch.org/whl/fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 194.2 MB/s  0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 52.7 MB/s  0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 226.7 MB/s  0:00:00
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 39.7 MB/s  0:00:14
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 35.9 MB/s  0:00:07
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 70.0 MB/s  0:00:01
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 72.0 MB/s  0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 68.4 MB/s  0:00:01
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 51.6 MB/s  0:00:03
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 74.3 MB/s  0:00:02
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==3.1.0 (from torch)
#   Downloading https://download.pytorch.org/whl/triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 52.4 MB/s  0:00:03
# Collecting setuptools (from torch)
#   Downloading https://download.pytorch.org/whl/setuptools-70.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 86.9 MB/s  0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading https://download.pytorch.org/whl/nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 25.4 MB/s  0:00:00
# Collecting numpy (from torchvision)
#   Downloading https://download.pytorch.org/whl/numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading https://download.pytorch.org/whl/pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading https://download.pytorch.org/whl/pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 107.5 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading https://download.pytorch.org/whl/filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading https://download.pytorch.org/whl/fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading https://download.pytorch.org/whl/networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 98.8 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 190.1 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 49.9 MB/s  0:00:00
# Downloading https://download.pytorch.org/whl/setuptools-70.2.0-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 60.0 MB/s  0:00:00
# Installing collected packages: mpmath, typing-extensions, sympy, setuptools, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.20.0
#     Uninstalling filelock-3.20.0:
#       Successfully uninstalled filelock-3.20.0
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.23.0+cu126
#     Uninstalling torchvision-0.23.0+cu126:
#       Successfully uninstalled torchvision-0.23.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.8.0+cu126
#     Uninstalling torchaudio-2.8.0+cu126:
#       Successfully uninstalled torchaudio-2.8.0+cu126
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [torchaudio]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.3 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.3 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 filelock-3.19.1 fsspec-2025.9.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.3.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.9.86 nvidia-nvtx-cu12-12.1.105 pillow-11.3.0 setuptools-70.2.0 sympy-1.13.1 torch-2.5.1+cu121 torchaudio-2.5.1+cu121 torchvision-0.20.1+cu121 triton-3.1.0 typing-extensions-4.15.0

# %%
# !pip install opencv-python h5py tqdm scipy scikit-image lpips kornia
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (3.15.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (0.25.2)
# Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.20.1+cu121)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=0.4.0->lpips) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (2.1.5)

# %%
import torch
import sys
print(f"Python: {sys.version}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.version.cuda}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# Python: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# PyTorch: 2.5.1+cu121
# CUDA: 12.1
# CUDA available: True

# %%
import os
print("Checking diff-gaussian-rasterization...")
rast_dir = "submodules/diff-gaussian-rasterization"
if os.path.exists(f"{rast_dir}/setup.py"):
    print(f"✓ setup.py found")
else:
    print(f"✗ setup.py NOT found - cloning submodule")
    # !git clone https://github.com/graphdeco-inria/diff-gaussian-rasterization {rast_dir}
# Out:
# Checking diff-gaussian-rasterization...
# ✗ setup.py NOT found - cloning submodule
# Cloning into 'submodules/diff-gaussian-rasterization'...
# remote: Enumerating objects: 329, done.
# remote: Total 329 (delta 0), reused 0 (delta 0), pack-reused 329 (from 1)
# Receiving objects: 100% (329/329), 111.52 KiB | 913.00 KiB/s, done.
# Resolving deltas: 100% (217/217), done.

# %%
# %cd submodules/diff-gaussian-rasterization
# !python setup.py install
# %cd ../..
# Out:
# /content/GazeGaussian/submodules/diff-gaussian-rasterization
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing diff_gaussian_rasterization.egg-info/PKG-INFO
# writing dependency_links to diff_gaussian_rasterization.egg-info/dependency_links.txt
# writing top-level names to diff_gaussian_rasterization.egg-info/top_level.txt
# reading manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# adding license file 'LICENSE.md'
# writing manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying diff_gaussian_rasterization/__init__.py -> build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization
# running build_ext
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'diff_gaussian_rasterization._C' extension
# Emitting ninja build file /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/build.ninja...
# Compiling objects...
# Using envvar MAX_JOBS (2) as the number of workers...
# ninja: no work to do.
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/backward.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/forward.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/rasterizer_impl.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/ext.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/rasterize_points.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# copying build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/__init__.py -> build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# copying build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# byte-compiling build/bdist.linux-x86_64/egg/diff_gaussian_rasterization/__init__.py to __init__.cpython-312.pyc
# creating stub loader for diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/diff_gaussian_rasterization/_C.py to _C.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# diff_gaussian_rasterization.__pycache__._C.cpython-312: module references __file__
# creating 'dist/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# removing '/usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# Extracting diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# Adding diff-gaussian-rasterization 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# Processing dependencies for diff-gaussian-rasterization==0.0.0
# Finished processing dependencies for diff-gaussian-rasterization==0.0.0
# /content/GazeGaussian

# %%
# Initialize and update submodules within diff-gaussian-rasterization
# %cd /content/GazeGaussian/submodules/diff-gaussian-rasterization
# !git submodule update --init --recursive
# %cd ../..
# Out:
# /content/GazeGaussian/submodules/diff-gaussian-rasterization
# /content/GazeGaussian

# %% [markdown]
# ## 3. Build CUDA Extensions

# %%
import os
os.environ['MAX_JOBS'] = '2'
os.environ['TORCH_CUDA_ARCH_LIST'] = '7.5;8.0;8.6'

# %cd /content/GazeGaussian
# %cd submodules/diff-gaussian-rasterization
# !python setup.py install
# %cd ../..
# Out:
# /content/GazeGaussian
# /content/GazeGaussian/submodules/diff-gaussian-rasterization
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating diff_gaussian_rasterization.egg-info
# writing diff_gaussian_rasterization.egg-info/PKG-INFO
# writing dependency_links to diff_gaussian_rasterization.egg-info/dependency_links.txt
# writing top-level names to diff_gaussian_rasterization.egg-info/top_level.txt
# writing manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# reading manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# adding license file 'LICENSE.md'
# writing manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-cpython-312
# creating build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization
# copying diff_gaussian_rasterization/__init__.py -> build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization
# running build_ext
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'diff_gaussian_rasterization._C' extension
# creating /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312
# creating /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer
# Emitting ninja build file /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/build.ninja...
# Compiling objects...
# Using envvar MAX_JOBS (2) as the number of workers...
# [1/5] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/forward.o.d -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.12/dist-packages/torch/include/TH -I/usr/local/lib/python3.12/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/forward.cu -o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/forward.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -I/content/GazeGaussian/submodules/diff-gaussian-rasterization/third_party/glm/ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=sm_75 -gencode=arch=compute_80,code=sm_80 -gencode=arch=compute_86,code=sm_86 -std=c++17
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# [2/5] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/backward.o.d -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.12/dist-packages/torch/include/TH -I/usr/local/lib/python3.12/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/backward.cu -o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/backward.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -I/content/GazeGaussian/submodules/diff-gaussian-rasterization/third_party/glm/ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=sm_75 -gencode=arch=compute_80,code=sm_80 -gencode=arch=compute_86,code=sm_86 -std=c++17
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# [3/5] c++ -MMD -MF /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/ext.o.d -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.12/dist-packages/torch/include/TH -I/usr/local/lib/python3.12/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/GazeGaussian/submodules/diff-gaussian-rasterization/ext.cpp -o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/ext.o -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# [4/5] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/rasterizer_impl.o.d -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.12/dist-packages/torch/include/TH -I/usr/local/lib/python3.12/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/rasterizer_impl.cu -o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/rasterizer_impl.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -I/content/GazeGaussian/submodules/diff-gaussian-rasterization/third_party/glm/ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=sm_75 -gencode=arch=compute_80,code=sm_80 -gencode=arch=compute_86,code=sm_86 -std=c++17
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/cuda_rasterizer/auxiliary.h(151): warning #177-D: variable "p_proj" was declared but never referenced
#    float3 p_proj = { p_hom.x * p_w, p_hom.y * p_w, p_hom.z * p_w };
#           ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# [5/5] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/rasterize_points.o.d -I/usr/local/lib/python3.12/dist-packages/torch/include -I/usr/local/lib/python3.12/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.12/dist-packages/torch/include/TH -I/usr/local/lib/python3.12/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.12 -c -c /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu -o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/rasterize_points.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -I/content/GazeGaussian/submodules/diff-gaussian-rasterization/third_party/glm/ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=sm_75 -gencode=arch=compute_80,code=sm_80 -gencode=arch=compute_86,code=sm_86 -std=c++17
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu: In function ‘std::tuple<int, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor> RasterizeGaussiansCUDA(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, float, const at::Tensor&, const at::Tensor&, const at::Tensor&, float, float, int, int, const at::Tensor&, int, const at::Tensor&, bool, bool)’:
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:140: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                            ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:186: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                          ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:264: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                        ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:304: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:455: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:498: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:541: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:580: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:655: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:697: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:740: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:91:776: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#    91 |           rendered = CudaRasterizer::Rasterizer::forward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu: In function ‘std::tuple<at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor> RasterizeGaussiansBackwardCUDA(const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, const at::Tensor&, float, const at::Tensor&, const at::Tensor&, const at::Tensor&, float, float, const at::Tensor&, const at::Tensor&, const at::Tensor&, int, const at::Tensor&, const at::Tensor&, int, const at::Tensor&, const at::Tensor&, bool)’:
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:101: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                     ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:147: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                   ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:182: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                      ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:221: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                             ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:342: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                      ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:385: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                 ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:428: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                            ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:467: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:523: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:568: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:612: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:857: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:903: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:947: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:989: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:1033: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:1076: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:1119: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:1163: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:1205: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:1244: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:1287: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:171:1333: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   171 |           CudaRasterizer::Rasterizer::backward(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu: In function ‘at::Tensor markVisible(at::Tensor&, at::Tensor&, at::Tensor&)’:
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:222:87: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   222 |         CudaRasterizer::Rasterizer::markVisible(P,
#       |                                                                                       ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:222:130: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   222 |         CudaRasterizer::Rasterizer::markVisible(P,
#       |                                                                                                                                  ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:222:173: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   222 |         CudaRasterizer::Rasterizer::markVisible(P,
#       |                                                                                                                                                                             ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# /content/GazeGaussian/submodules/diff-gaussian-rasterization/rasterize_points.cu:222:212: warning: ‘T* at::Tensor::data() const [with T = bool]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   222 |         CudaRasterizer::Rasterizer::markVisible(P,
#       |                                                                                                                                                                                                                    ^
# /usr/local/lib/python3.12/dist-packages/torch/include/ATen/core/TensorBody.h:247:1: note: declared here
#   247 |   T * data() const {
#       | ^ ~~
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/backward.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/forward.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/rasterizer_impl.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/ext.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/rasterize_points.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# copying build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/__init__.py -> build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# copying build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# byte-compiling build/bdist.linux-x86_64/egg/diff_gaussian_rasterization/__init__.py to __init__.cpython-312.pyc
# creating stub loader for diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/diff_gaussian_rasterization/_C.py to _C.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# diff_gaussian_rasterization.__pycache__._C.cpython-312: module references __file__
# creating dist
# creating 'dist/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# creating /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# Extracting diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# Adding diff-gaussian-rasterization 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# Processing dependencies for diff-gaussian-rasterization==0.0.0
# Finished processing dependencies for diff-gaussian-rasterization==0.0.0
# /content/GazeGaussian

# %%
import os

# Change to the main GazeGaussian directory first
os.chdir('/content/GazeGaussian')

# Clone the simple-knn submodule if it doesn't exist
simple_knn_dir = "submodules/simple-knn"
if not os.path.exists(simple_knn_dir):
    print(f"Cloning simple-knn submodule into {simple_knn_dir}...")
    os.system(f'git clone https://github.com/rusty1s/simple-knn {simple_knn_dir}')
else:
    print(f"simple-knn submodule already exists at {simple_knn_dir}")

# Now change to the simple-knn directory
os.chdir(simple_knn_dir)

with open('simple_knn.cu', 'r') as f:
    content = f.read()

if '#include <cfloat>' not in content:
    content = content.replace(
        '#include <vector>',
        '#include <vector>\n#include <cfloat>'
    )
    with open('simple_knn.cu', 'w') as f:
        f.write(content)
    print("✓ Added cfloat header")
else:
    print("✓ cfloat header already present")

os.system('python setup.py install')
os.chdir('/content/GazeGaussian')
# Out:
# simple-knn submodule already exists at submodules/simple-knn
# ✓ cfloat header already present

# %%
import os
os.chdir('/content/GazeGaussian/submodules/simple-knn')
with open('simple_knn.cu', 'r') as f:
    content = f.read()
if '#include <cfloat>' not in content:
    content = content.replace('#include <vector>', '#include <vector>\n#include <cfloat>')
    with open('simple_knn.cu', 'w') as f:
        f.write(content)
os.chdir('/content/GazeGaussian')

# %cd submodules/simple-knn
# !python setup.py install
# %cd ../..
# Out:
# /content/GazeGaussian/submodules/simple-knn
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing simple_knn.egg-info/PKG-INFO
# writing dependency_links to simple_knn.egg-info/dependency_links.txt
# writing top-level names to simple_knn.egg-info/top_level.txt
# reading manifest file 'simple_knn.egg-info/SOURCES.txt'
# writing manifest file 'simple_knn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'simple_knn._C' extension
# Emitting ninja build file /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/build.ninja...
# Compiling objects...
# Using envvar MAX_JOBS (2) as the number of workers...
# ninja: no work to do.
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/ext.o /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/simple_knn.o /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/spatial.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/simple_knn/_C.cpython-312-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/simple_knn
# copying build/lib.linux-x86_64-cpython-312/simple_knn/_C.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/simple_knn
# creating stub loader for simple_knn/_C.cpython-312-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/simple_knn/_C.py to _C.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# simple_knn.__pycache__._C.cpython-312: module references __file__
# creating 'dist/simple_knn-0.0.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing simple_knn-0.0.0-py3.12-linux-x86_64.egg
# removing '/usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg
# Extracting simple_knn-0.0.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# Adding simple-knn 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg
# Processing dependencies for simple-knn==0.0.0
# Finished processing dependencies for simple-knn==0.0.0
# /content/GazeGaussian

# %%
# %cd /content
# !git clone --recursive https://github.com/NVIDIAGameWorks/kaolin
# %cd kaolin
# !python setup.py install
# %cd /content/GazeGaussian
# Out:
# /content
# Cloning into 'kaolin'...
# remote: Enumerating objects: 6543, done.
# remote: Counting objects: 100% (722/722), done.
# remote: Compressing objects: 100% (276/276), done.
# remote: Total 6543 (delta 561), reused 446 (delta 446), pack-reused 5821 (from 2)
# Receiving objects: 100% (6543/6543), 133.24 MiB | 38.85 MiB/s, done.
# Resolving deltas: 100% (3570/3570), done.
# Submodule 'third_party/cub' (https://github.com/NVIDIA/cub) registered for path 'third_party/cub'
# Cloning into '/content/kaolin/third_party/cub'...
# remote: Enumerating objects: 33392, done.
# remote: Counting objects: 100% (247/247), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 33392 (delta 209), reused 184 (delta 184), pack-reused 33145 (from 4)
# Receiving objects: 100% (33392/33392), 18.00 MiB | 22.13 MiB/s, done.
# Resolving deltas: 100% (27972/27972), done.
# Submodule path 'third_party/cub': checked out '499a7bad3416fcc71a7c50351d6b3cdbf3fbbc27'
# /content/kaolin
# /content/kaolin/setup.py:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import parse_version
# Warning: passing language='c++' to cythonize() is deprecated. Instead, put "# distutils: language=c++" in your .pyx or .pxd file(s)
# Compiling kaolin/cython/ops/conversions/mise.pyx because it changed.
# [1/1] Cythonizing kaolin/cython/ops/conversions/mise.pyx
# /usr/local/lib/python3.12/dist-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /content/kaolin/kaolin/cython/ops/conversions/mise.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: kaolin/cython/ops/conversions/mise.pyx:209:9: Only extern functions can throw C++ exceptions.
# warning: kaolin/cython/ops/conversions/mise.pyx:309:9: Only extern functions can throw C++ exceptions.
# warning: kaolin/cython/ops/conversions/mise.pyx:90:33: Not all members given for struct 'Voxel'
# warning: kaolin/cython/ops/conversions/mise.pyx:90:33: Not all members given for struct 'Voxel'
# warning: kaolin/cython/ops/conversions/mise.pyx:284:33: Not all members given for struct 'Voxel'
# warning: kaolin/cython/ops/conversions/mise.pyx:284:33: Not all members given for struct 'Voxel'
# INFO - running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# INFO - running bdist_egg
# INFO - running egg_info
# INFO - creating kaolin.egg-info
# INFO - writing kaolin.egg-info/PKG-INFO
# INFO - writing dependency_links to kaolin.egg-info/dependency_links.txt
# INFO - writing requirements to kaolin.egg-info/requires.txt
# INFO - writing top-level names to kaolin.egg-info/top_level.txt
# INFO - writing manifest file 'kaolin.egg-info/SOURCES.txt'
# INFO - reading manifest file 'kaolin.egg-info/SOURCES.txt'
# INFO - reading manifest template 'MANIFEST.in'
# INFO - adding license file 'LICENSE'
# INFO - adding license file 'LICENSE.NSCL'
# INFO - writing manifest file 'kaolin.egg-info/SOURCES.txt'
# INFO - installing library code to build/bdist.linux-x86_64/egg
# INFO - running install_lib
# INFO - running build_py
# INFO - creating build
# INFO - creating build/lib.linux-x86_64-cpython-312
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin
# INFO - copying kaolin/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin
# INFO - copying kaolin/version.py -> build/lib.linux-x86_64-cpython-312/kaolin
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/trianglemesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/pointcloud.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/voxelgrid.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/render.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/tetmesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/experimental
# INFO - copying kaolin/experimental/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/experimental
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/non_commercial
# INFO - copying kaolin/non_commercial/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/non_commercial
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/math
# INFO - copying kaolin/math/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/math
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/reduction.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/random.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/batch.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/gcn.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/pointcloud.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/voxelgrid.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/coords.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/materials.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/obj.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/utils.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/off.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/gltf.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/shapenet.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/modelnet.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/render.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/shrec.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/dataset.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics
# INFO - copying kaolin/physics/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render
# INFO - copying kaolin/render/materials.py -> build/lib.linux-x86_64-cpython-312/kaolin/render
# INFO - copying kaolin/render/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/utils
# INFO - copying kaolin/utils/testing.py -> build/lib.linux-x86_64-cpython-312/kaolin/utils
# INFO - copying kaolin/utils/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/utils
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/rep
# INFO - copying kaolin/rep/surface_mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/rep
# INFO - copying kaolin/rep/spc.py -> build/lib.linux-x86_64-cpython-312/kaolin/rep
# INFO - copying kaolin/rep/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/rep
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/visualize
# INFO - copying kaolin/visualize/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/visualize
# INFO - copying kaolin/visualize/ipython.py -> build/lib.linux-x86_64-cpython-312/kaolin/visualize
# INFO - copying kaolin/visualize/timelapse.py -> build/lib.linux-x86_64-cpython-312/kaolin/visualize
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/experimental/dash3d
# INFO - copying kaolin/experimental/dash3d/util.py -> build/lib.linux-x86_64-cpython-312/kaolin/experimental/dash3d
# INFO - copying kaolin/experimental/dash3d/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/experimental/dash3d
# INFO - copying kaolin/experimental/dash3d/run.py -> build/lib.linux-x86_64-cpython-312/kaolin/experimental/dash3d
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/non_commercial/flexicubes
# INFO - copying kaolin/non_commercial/flexicubes/tables.py -> build/lib.linux-x86_64-cpython-312/kaolin/non_commercial/flexicubes
# INFO - copying kaolin/non_commercial/flexicubes/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/non_commercial/flexicubes
# INFO - copying kaolin/non_commercial/flexicubes/flexicubes.py -> build/lib.linux-x86_64-cpython-312/kaolin/non_commercial/flexicubes
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/transform.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/rotation33.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/matrix44.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/angle_axis.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/util.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/quaternion.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/euclidean.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/trianglemesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/check_sign.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/tetmesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/convolution.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/uint8.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/raytraced_spc_dataset.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/spc.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/bf_recon.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/points.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/trianglemesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/pointcloud.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/gaussians.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/voxelgrid.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/tetmesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/sdf.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/gaussian
# INFO - copying kaolin/ops/gaussian/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/gaussian
# INFO - copying kaolin/ops/gaussian/densifier.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/gaussian
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions/flexicubes
# INFO - copying kaolin/ops/conversions/flexicubes/tables.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions/flexicubes
# INFO - copying kaolin/ops/conversions/flexicubes/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions/flexicubes
# INFO - copying kaolin/ops/conversions/flexicubes/flexicubes.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions/flexicubes
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/materials.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/utils.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/pointcloud.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/voxelgrid.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - copying kaolin/physics/common/collisions.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - copying kaolin/physics/common/scene_forces.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - copying kaolin/physics/common/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - copying kaolin/physics/common/optimization.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/skinning.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/losses_warp.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/precomputed.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/losses.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/easy_api.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/network.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - copying kaolin/physics/utils/finite_diff.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - copying kaolin/physics/utils/warp_utilities.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - copying kaolin/physics/utils/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - copying kaolin/physics/utils/torch_utilities.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - copying kaolin/physics/materials/linear_elastic_material.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - copying kaolin/physics/materials/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - copying kaolin/physics/materials/material_utils.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - copying kaolin/physics/materials/neohookean_elastic_material.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/rasterization.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/deftet.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/utils.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/nvdiffrast_context.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/dibr.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/spc
# INFO - copying kaolin/render/spc/raytrace.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/spc
# INFO - copying kaolin/render/spc/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/spc
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/intrinsics_pinhole.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/legacy.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/coordinates.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/extrinsics_backends.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/polyscope.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/gsplats.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/camera.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/trajectory.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/intrinsics_ortho.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/raygen.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/intrinsics.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/extrinsics.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/lighting
# INFO - copying kaolin/render/lighting/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/lighting
# INFO - copying kaolin/render/lighting/sh.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/lighting
# INFO - copying kaolin/render/lighting/sg.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/lighting
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/easy_render
# INFO - copying kaolin/render/easy_render/common.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/easy_render
# INFO - copying kaolin/render/easy_render/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/easy_render
# INFO - copying kaolin/render/easy_render/mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/easy_render
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.metrics' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.metrics' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.metrics' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.metrics' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.metrics' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.conversions.gs_to_spc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.conversions.gs_to_spc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.conversions.gs_to_spc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.conversions.gs_to_spc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.conversions.gs_to_spc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.conversions.mesh_to_spc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.conversions.mesh_to_spc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.conversions.mesh_to_spc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.conversions.mesh_to_spc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.conversions.mesh_to_spc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.conversions.unbatched_mcube' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.conversions.unbatched_mcube' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.conversions.unbatched_mcube' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.conversions.unbatched_mcube' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.conversions.unbatched_mcube' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.mesh' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.mesh' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.mesh' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.mesh' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.mesh' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.spc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.spc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.spc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.spc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.spc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.render.mesh' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.render.mesh' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.render.mesh' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.render.mesh' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.render.mesh' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.render.sg' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.render.sg' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.render.sg' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.render.sg' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.render.sg' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.render.spc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.render.spc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.render.spc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.render.spc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.render.spc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.cython.ops.conversions' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.cython.ops.conversions' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.cython.ops.conversions' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.cython.ops.conversions' to be distributed and are
#         already explicitly excluding 'kaolin.cython.ops.conversions' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.experimental.dash3d.static' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.experimental.dash3d.static' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.experimental.dash3d.static' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.experimental.dash3d.static' to be distributed and are
#         already explicitly excluding 'kaolin.experimental.dash3d.static' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.experimental.dash3d.templates' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.experimental.dash3d.templates' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.experimental.dash3d.templates' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
# ...
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/matrix44.py to matrix44.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/angle_axis.py to angle_axis.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/util.py to util.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/quaternion.py to quaternion.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/euclidean.py to euclidean.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/reduction.py to reduction.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/trianglemesh.py to trianglemesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/mesh.py to mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/check_sign.py to check_sign.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/tetmesh.py to tetmesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/convolution.py to convolution.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/uint8.py to uint8.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/raytraced_spc_dataset.py to raytraced_spc_dataset.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/spc.py to spc.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/bf_recon.py to bf_recon.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/points.py to points.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/random.py to random.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/batch.py to batch.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/gcn.py to gcn.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/trianglemesh.py to trianglemesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/pointcloud.py to pointcloud.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/flexicubes/tables.py to tables.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/flexicubes/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/flexicubes/flexicubes.py to flexicubes.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/gaussians.py to gaussians.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/voxelgrid.py to voxelgrid.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/tetmesh.py to tetmesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/sdf.py to sdf.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/pointcloud.py to pointcloud.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/voxelgrid.py to voxelgrid.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/gaussian/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/gaussian/densifier.py to densifier.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/coords.py to coords.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/materials.py to materials.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/obj.py to obj.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/utils.py to utils.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/mesh.py to mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/off.py to off.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/gltf.py to gltf.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/shapenet.py to shapenet.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/materials.py to materials.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/utils.py to utils.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/pointcloud.py to pointcloud.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/mesh.py to mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/voxelgrid.py to voxelgrid.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/modelnet.py to modelnet.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/render.py to render.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/shrec.py to shrec.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/dataset.py to dataset.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/version.py to version.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/common/collisions.py to collisions.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/common/scene_forces.py to scene_forces.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/common/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/common/optimization.py to optimization.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/skinning.py to skinning.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/losses_warp.py to losses_warp.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/precomputed.py to precomputed.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/losses.py to losses.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/easy_api.py to easy_api.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/network.py to network.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/utils/finite_diff.py to finite_diff.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/utils/warp_utilities.py to warp_utilities.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/utils/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/utils/torch_utilities.py to torch_utilities.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/materials/linear_elastic_material.py to linear_elastic_material.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/materials/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/materials/material_utils.py to material_utils.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/materials/neohookean_elastic_material.py to neohookean_elastic_material.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/materials.py to materials.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/rasterization.py to rasterization.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/deftet.py to deftet.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/utils.py to utils.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/nvdiffrast_context.py to nvdiffrast_context.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/dibr.py to dibr.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/spc/raytrace.py to raytrace.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/spc/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/intrinsics_pinhole.py to intrinsics_pinhole.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/legacy.py to legacy.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/coordinates.py to coordinates.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/extrinsics_backends.py to extrinsics_backends.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/polyscope.py to polyscope.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/gsplats.py to gsplats.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/camera.py to camera.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/trajectory.py to trajectory.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/intrinsics_ortho.py to intrinsics_ortho.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/raygen.py to raygen.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/intrinsics.py to intrinsics.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/extrinsics.py to extrinsics.cpython-312.pyc
# build/bdist.linux-x86_64/egg/kaolin/render/camera/extrinsics.py:192: SyntaxWarning: invalid escape sequence '\:'
#   Values supported by default\: ``matrix_se3``, ``matrix_6dof_rotation`` (see class description).
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/lighting/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/lighting/sh.py to sh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/lighting/sg.py to sg.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/easy_render/common.py to common.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/easy_render/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/easy_render/mesh.py to mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/utils/testing.py to testing.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/utils/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/rep/surface_mesh.py to surface_mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/rep/spc.py to spc.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/rep/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/visualize/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/visualize/ipython.py to ipython.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/visualize/timelapse.py to timelapse.cpython-312.pyc
# INFO - creating stub loader for kaolin/_C.so
# INFO - creating stub loader for kaolin/ops/conversions/mise.so
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/_C.py to _C.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/mise.py to mise.cpython-312.pyc
# INFO - creating build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - installing scripts to build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# INFO - running install_scripts
# INFO - running build_scripts
# INFO - creating build/scripts-3.12
# INFO - copying and adjusting kaolin/experimental/dash3d/kaolin-dash3d -> build/scripts-3.12
# INFO - changing mode of build/scripts-3.12/kaolin-dash3d from 644 to 755
# INFO - creating build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# INFO - copying build/scripts-3.12/kaolin-dash3d -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# INFO - changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/kaolin-dash3d to 755
# INFO - copying kaolin.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# INFO - creating dist
# INFO - creating 'dist/kaolin-0.18.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# INFO - removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# INFO - Processing kaolin-0.18.0-py3.12-linux-x86_64.egg
# INFO - creating /usr/local/lib/python3.12/dist-packages/kaolin-0.18.0-py3.12-linux-x86_64.egg
# INFO - Extracting kaolin-0.18.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# /usr/local/lib/python3.12/dist-packages/kaolin-0.18.0-py3.12-linux-x86_64.egg/kaolin/render/camera/extrinsics.py:192: SyntaxWarning: invalid escape sequence '\:'
#   Values supported by default\: ``matrix_se3``, ``matrix_6dof_rotation`` (see class description).
# INFO - Adding kaolin 0.18.0 to easy-install.pth file
# INFO - Installing kaolin-dash3d script to /usr/local/bin
# INFO -
# Installed /usr/local/lib/python3.12/dist-packages/kaolin-0.18.0-py3.12-linux-x86_64.egg
# INFO - Processing dependencies for kaolin==0.18.0
# INFO - Searching for warp-lang
# INFO - Reading https://pypi.org/simple/warp-lang/
# INFO - Downloading https://files.pythonhosted.org/packages/dc/df/8849e44300d805096f94978a8e92fa48f4e79ebafb45042d3a68f9b3fd94/warp_lang-1.11.0.dev20251030.tar.gz#sha256=655d47582974849b90063416938c3019898d08d654c07335da3c1d143922fb1d
# INFO - Best match: warp-lang 1.11.0.dev20251030
# INFO - Processing warp_lang-1.11.0.dev20251030.tar.gz
# error: Couldn't find a setup script in /tmp/easy_install-5yd81stg/warp_lang-1.11.0.dev20251030.tar.gz
# /content/GazeGaussian

# %%
import os
os.environ['MAX_JOBS'] = '2'
os.environ['TORCH_CUDA_ARCH_LIST'] = '7.5;8.0;8.6'

# %cd submodules/diff-gaussian-rasterization
# !python setup.py install
# %cd ../..
# Out:
# /content/GazeGaussian/submodules/diff-gaussian-rasterization
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing diff_gaussian_rasterization.egg-info/PKG-INFO
# writing dependency_links to diff_gaussian_rasterization.egg-info/dependency_links.txt
# writing top-level names to diff_gaussian_rasterization.egg-info/top_level.txt
# reading manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# adding license file 'LICENSE.md'
# writing manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying diff_gaussian_rasterization/__init__.py -> build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization
# running build_ext
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'diff_gaussian_rasterization._C' extension
# Emitting ninja build file /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/build.ninja...
# Compiling objects...
# Using envvar MAX_JOBS (2) as the number of workers...
# ninja: no work to do.
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/backward.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/forward.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/rasterizer_impl.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/ext.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/rasterize_points.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# copying build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/__init__.py -> build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# copying build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# byte-compiling build/bdist.linux-x86_64/egg/diff_gaussian_rasterization/__init__.py to __init__.cpython-312.pyc
# creating stub loader for diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/diff_gaussian_rasterization/_C.py to _C.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# diff_gaussian_rasterization.__pycache__._C.cpython-312: module references __file__
# creating 'dist/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# removing '/usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# Extracting diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# Adding diff-gaussian-rasterization 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# Processing dependencies for diff-gaussian-rasterization==0.0.0
# Finished processing dependencies for diff-gaussian-rasterization==0.0.0
# /content/GazeGaussian

# %%
import os
os.chdir('/content/GazeGaussian/submodules/simple-knn')
with open('simple_knn.cu', 'r') as f:
    content = f.read()
if '#include <cfloat>' not in content:
    content = content.replace('#include <vector>', '#include <vector>\n#include <cfloat>')
    with open('simple_knn.cu', 'w') as f:
        f.write(content)
os.chdir('/content/GazeGaussian')

# %cd submodules/simple-knn
# !python setup.py install
# %cd ../..
# Out:
# /content/GazeGaussian/submodules/simple-knn
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing simple_knn.egg-info/PKG-INFO
# writing dependency_links to simple_knn.egg-info/dependency_links.txt
# writing top-level names to simple_knn.egg-info/top_level.txt
# reading manifest file 'simple_knn.egg-info/SOURCES.txt'
# writing manifest file 'simple_knn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'simple_knn._C' extension
# Emitting ninja build file /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/build.ninja...
# Compiling objects...
# Using envvar MAX_JOBS (2) as the number of workers...
# ninja: no work to do.
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/ext.o /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/simple_knn.o /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/spatial.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/simple_knn/_C.cpython-312-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/simple_knn
# copying build/lib.linux-x86_64-cpython-312/simple_knn/_C.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/simple_knn
# creating stub loader for simple_knn/_C.cpython-312-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/simple_knn/_C.py to _C.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# simple_knn.__pycache__._C.cpython-312: module references __file__
# creating 'dist/simple_knn-0.0.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing simple_knn-0.0.0-py3.12-linux-x86_64.egg
# removing '/usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg
# Extracting simple_knn-0.0.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# Adding simple-knn 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg
# Processing dependencies for simple-knn==0.0.0
# Finished processing dependencies for simple-knn==0.0.0
# /content/GazeGaussian

# %%
# !pip install lpips kornia
# Out:
# Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.20.1+cu121)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.2.6)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.2)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.1)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=0.4.0->lpips) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.2.1->lpips) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (2.1.5)

# %%
import os
os.environ['MAX_JOBS'] = '2'
os.environ['TORCH_CUDA_ARCH_LIST'] = '7.5;8.0;8.6'

# %cd submodules/diff-gaussian-rasterization
# !python setup.py install
# %cd ../..
# Out:
# /content/GazeGaussian/submodules/diff-gaussian-rasterization
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing diff_gaussian_rasterization.egg-info/PKG-INFO
# writing dependency_links to diff_gaussian_rasterization.egg-info/dependency_links.txt
# writing top-level names to diff_gaussian_rasterization.egg-info/top_level.txt
# reading manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# adding license file 'LICENSE.md'
# writing manifest file 'diff_gaussian_rasterization.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying diff_gaussian_rasterization/__init__.py -> build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization
# running build_ext
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'diff_gaussian_rasterization._C' extension
# Emitting ninja build file /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/build.ninja...
# Compiling objects...
# Using envvar MAX_JOBS (2) as the number of workers...
# ninja: no work to do.
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/backward.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/forward.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/cuda_rasterizer/rasterizer_impl.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/ext.o /content/GazeGaussian/submodules/diff-gaussian-rasterization/build/temp.linux-x86_64-cpython-312/rasterize_points.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# copying build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/__init__.py -> build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# copying build/lib.linux-x86_64-cpython-312/diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/diff_gaussian_rasterization
# byte-compiling build/bdist.linux-x86_64/egg/diff_gaussian_rasterization/__init__.py to __init__.cpython-312.pyc
# creating stub loader for diff_gaussian_rasterization/_C.cpython-312-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/diff_gaussian_rasterization/_C.py to _C.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying diff_gaussian_rasterization.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# diff_gaussian_rasterization.__pycache__._C.cpython-312: module references __file__
# creating 'dist/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# removing '/usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# Extracting diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# Adding diff-gaussian-rasterization 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/diff_gaussian_rasterization-0.0.0-py3.12-linux-x86_64.egg
# Processing dependencies for diff-gaussian-rasterization==0.0.0
# Finished processing dependencies for diff-gaussian-rasterization==0.0.0
# /content/GazeGaussian

# %%
import os
os.chdir('/content/GazeGaussian/submodules/simple-knn')
with open('simple_knn.cu', 'r') as f:
    content = f.read()
if '#include <cfloat>' not in content:
    content = content.replace('#include <vector>', '#include <vector>\n#include <cfloat>')
    with open('simple_knn.cu', 'w') as f:
        f.write(content)
os.chdir('/content/GazeGaussian')

# %cd submodules/simple-knn
# !python setup.py install
# %cd ../..
# Out:
# /content/GazeGaussian/submodules/simple-knn
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing simple_knn.egg-info/PKG-INFO
# writing dependency_links to simple_knn.egg-info/dependency_links.txt
# writing top-level names to simple_knn.egg-info/top_level.txt
# reading manifest file 'simple_knn.egg-info/SOURCES.txt'
# writing manifest file 'simple_knn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.5) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.12/dist-packages/torch/utils/cpp_extension.py:426: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.5
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'simple_knn._C' extension
# Emitting ninja build file /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/build.ninja...
# Compiling objects...
# Using envvar MAX_JOBS (2) as the number of workers...
# ninja: no work to do.
# x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/ext.o /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/simple_knn.o /content/GazeGaussian/submodules/simple-knn/build/temp.linux-x86_64-cpython-312/spatial.o -L/usr/local/lib/python3.12/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-312/simple_knn/_C.cpython-312-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/simple_knn
# copying build/lib.linux-x86_64-cpython-312/simple_knn/_C.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/simple_knn
# creating stub loader for simple_knn/_C.cpython-312-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/simple_knn/_C.py to _C.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying simple_knn.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# simple_knn.__pycache__._C.cpython-312: module references __file__
# creating 'dist/simple_knn-0.0.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing simple_knn-0.0.0-py3.12-linux-x86_64.egg
# removing '/usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg
# Extracting simple_knn-0.0.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# Adding simple-knn 0.0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.12/dist-packages/simple_knn-0.0.0-py3.12-linux-x86_64.egg
# Processing dependencies for simple-knn==0.0.0
# Finished processing dependencies for simple-knn==0.0.0
# /content/GazeGaussian

# %%
import os
os.environ['IGNORE_TORCH_VER'] = '1'
os.environ['FORCE_CUDA'] = '1'

# %cd /content/kaolin
# !python setup.py clean --all
# !python setup.py install
# %cd /content/GazeGaussian
print("✓ Kaolin reinstalled from source")
# Out:
# /content/kaolin
# /content/kaolin/setup.py:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import parse_version
# Warning: passing language='c++' to cythonize() is deprecated. Instead, put "# distutils: language=c++" in your .pyx or .pxd file(s)
# INFO - running clean
# INFO - removing 'build/temp.linux-x86_64-cpython-312' (and everything under it)
# INFO - removing 'build/lib.linux-x86_64-cpython-312' (and everything under it)
# INFO - removing 'build/bdist.linux-x86_64' (and everything under it)
# INFO - removing 'build/scripts-3.12' (and everything under it)
# INFO - removing 'build'
# /content/kaolin/setup.py:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import parse_version
# Warning: passing language='c++' to cythonize() is deprecated. Instead, put "# distutils: language=c++" in your .pyx or .pxd file(s)
# INFO - running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# INFO - running bdist_egg
# INFO - running egg_info
# INFO - writing kaolin.egg-info/PKG-INFO
# INFO - writing dependency_links to kaolin.egg-info/dependency_links.txt
# INFO - writing requirements to kaolin.egg-info/requires.txt
# INFO - writing top-level names to kaolin.egg-info/top_level.txt
# INFO - reading manifest file 'kaolin.egg-info/SOURCES.txt'
# INFO - reading manifest template 'MANIFEST.in'
# INFO - adding license file 'LICENSE'
# INFO - adding license file 'LICENSE.NSCL'
# INFO - writing manifest file 'kaolin.egg-info/SOURCES.txt'
# INFO - installing library code to build/bdist.linux-x86_64/egg
# INFO - running install_lib
# INFO - running build_py
# INFO - creating build
# INFO - creating build/lib.linux-x86_64-cpython-312
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin
# INFO - copying kaolin/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin
# INFO - copying kaolin/version.py -> build/lib.linux-x86_64-cpython-312/kaolin
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/trianglemesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/pointcloud.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/voxelgrid.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/render.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - copying kaolin/metrics/tetmesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/metrics
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/experimental
# INFO - copying kaolin/experimental/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/experimental
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/non_commercial
# INFO - copying kaolin/non_commercial/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/non_commercial
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/math
# INFO - copying kaolin/math/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/math
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/reduction.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/random.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/batch.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/gcn.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/pointcloud.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/voxelgrid.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - copying kaolin/ops/coords.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/materials.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/obj.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/utils.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/off.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/gltf.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/shapenet.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/modelnet.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/render.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/shrec.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - copying kaolin/io/dataset.py -> build/lib.linux-x86_64-cpython-312/kaolin/io
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics
# INFO - copying kaolin/physics/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render
# INFO - copying kaolin/render/materials.py -> build/lib.linux-x86_64-cpython-312/kaolin/render
# INFO - copying kaolin/render/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/utils
# INFO - copying kaolin/utils/testing.py -> build/lib.linux-x86_64-cpython-312/kaolin/utils
# INFO - copying kaolin/utils/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/utils
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/rep
# INFO - copying kaolin/rep/surface_mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/rep
# INFO - copying kaolin/rep/spc.py -> build/lib.linux-x86_64-cpython-312/kaolin/rep
# INFO - copying kaolin/rep/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/rep
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/visualize
# INFO - copying kaolin/visualize/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/visualize
# INFO - copying kaolin/visualize/ipython.py -> build/lib.linux-x86_64-cpython-312/kaolin/visualize
# INFO - copying kaolin/visualize/timelapse.py -> build/lib.linux-x86_64-cpython-312/kaolin/visualize
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/experimental/dash3d
# INFO - copying kaolin/experimental/dash3d/util.py -> build/lib.linux-x86_64-cpython-312/kaolin/experimental/dash3d
# INFO - copying kaolin/experimental/dash3d/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/experimental/dash3d
# INFO - copying kaolin/experimental/dash3d/run.py -> build/lib.linux-x86_64-cpython-312/kaolin/experimental/dash3d
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/non_commercial/flexicubes
# INFO - copying kaolin/non_commercial/flexicubes/tables.py -> build/lib.linux-x86_64-cpython-312/kaolin/non_commercial/flexicubes
# INFO - copying kaolin/non_commercial/flexicubes/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/non_commercial/flexicubes
# INFO - copying kaolin/non_commercial/flexicubes/flexicubes.py -> build/lib.linux-x86_64-cpython-312/kaolin/non_commercial/flexicubes
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/transform.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/rotation33.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/matrix44.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/angle_axis.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/util.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/quaternion.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - copying kaolin/math/quat/euclidean.py -> build/lib.linux-x86_64-cpython-312/kaolin/math/quat
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/trianglemesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/check_sign.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - copying kaolin/ops/mesh/tetmesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/mesh
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/convolution.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/uint8.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/raytraced_spc_dataset.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/spc.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/bf_recon.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - copying kaolin/ops/spc/points.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/spc
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/trianglemesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/pointcloud.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/gaussians.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/voxelgrid.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/tetmesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - copying kaolin/ops/conversions/sdf.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/gaussian
# INFO - copying kaolin/ops/gaussian/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/gaussian
# INFO - copying kaolin/ops/gaussian/densifier.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/gaussian
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions/flexicubes
# INFO - copying kaolin/ops/conversions/flexicubes/tables.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions/flexicubes
# INFO - copying kaolin/ops/conversions/flexicubes/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions/flexicubes
# INFO - copying kaolin/ops/conversions/flexicubes/flexicubes.py -> build/lib.linux-x86_64-cpython-312/kaolin/ops/conversions/flexicubes
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/materials.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/utils.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/pointcloud.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - copying kaolin/io/usd/voxelgrid.py -> build/lib.linux-x86_64-cpython-312/kaolin/io/usd
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - copying kaolin/physics/common/collisions.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - copying kaolin/physics/common/scene_forces.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - copying kaolin/physics/common/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - copying kaolin/physics/common/optimization.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/common
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/skinning.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/losses_warp.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/precomputed.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/losses.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/easy_api.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - copying kaolin/physics/simplicits/network.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/simplicits
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - copying kaolin/physics/utils/finite_diff.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - copying kaolin/physics/utils/warp_utilities.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - copying kaolin/physics/utils/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - copying kaolin/physics/utils/torch_utilities.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/utils
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - copying kaolin/physics/materials/linear_elastic_material.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - copying kaolin/physics/materials/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - copying kaolin/physics/materials/material_utils.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - copying kaolin/physics/materials/neohookean_elastic_material.py -> build/lib.linux-x86_64-cpython-312/kaolin/physics/materials
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/rasterization.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/deftet.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/utils.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/nvdiffrast_context.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - copying kaolin/render/mesh/dibr.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/mesh
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/spc
# INFO - copying kaolin/render/spc/raytrace.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/spc
# INFO - copying kaolin/render/spc/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/spc
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/intrinsics_pinhole.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/legacy.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/coordinates.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/extrinsics_backends.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/polyscope.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/gsplats.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/camera.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/trajectory.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/intrinsics_ortho.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/raygen.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/intrinsics.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - copying kaolin/render/camera/extrinsics.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/camera
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/lighting
# INFO - copying kaolin/render/lighting/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/lighting
# INFO - copying kaolin/render/lighting/sh.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/lighting
# INFO - copying kaolin/render/lighting/sg.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/lighting
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/render/easy_render
# INFO - copying kaolin/render/easy_render/common.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/easy_render
# INFO - copying kaolin/render/easy_render/__init__.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/easy_render
# INFO - copying kaolin/render/easy_render/mesh.py -> build/lib.linux-x86_64-cpython-312/kaolin/render/easy_render
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.metrics' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.metrics' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.metrics' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.metrics' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.metrics' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.conversions.gs_to_spc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.conversions.gs_to_spc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.conversions.gs_to_spc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.conversions.gs_to_spc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.conversions.gs_to_spc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.conversions.mesh_to_spc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.conversions.mesh_to_spc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.conversions.mesh_to_spc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.conversions.mesh_to_spc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.conversions.mesh_to_spc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.conversions.unbatched_mcube' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.conversions.unbatched_mcube' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.conversions.unbatched_mcube' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.conversions.unbatched_mcube' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.conversions.unbatched_mcube' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.mesh' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.mesh' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.mesh' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.mesh' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.mesh' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.ops.spc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.ops.spc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.ops.spc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.ops.spc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.ops.spc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.render.mesh' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.render.mesh' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.render.mesh' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.render.mesh' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.render.mesh' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.render.sg' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.render.sg' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.render.sg' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.render.sg' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.render.sg' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.csrc.render.spc' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.csrc.render.spc' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.csrc.render.spc' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.csrc.render.spc' to be distributed and are
#         already explicitly excluding 'kaolin.csrc.render.spc' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.cython.ops.conversions' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.cython.ops.conversions' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.cython.ops.conversions' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.cython.ops.conversions' to be distributed and are
#         already explicitly excluding 'kaolin.cython.ops.conversions' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.experimental.dash3d.static' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.experimental.dash3d.static' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.experimental.dash3d.static' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.experimental.dash3d.static' to be distributed and are
#         already explicitly excluding 'kaolin.experimental.dash3d.static' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# /usr/local/lib/python3.12/dist-packages/setuptools/command/build_py.py:215: _Warning: Package 'kaolin.experimental.dash3d.templates' is absent from the `packages` configuration.
# !!
#
#         ********************************************************************************
#         ############################
#         # Package would be ignored #
#         ############################
#         Python recognizes 'kaolin.experimental.dash3d.templates' as an importable package[^1],
#         but it is absent from setuptools' `packages` configuration.
#
#         This leads to an ambiguous overall configuration. If you want to distribute this
#         package, please make sure that 'kaolin.experimental.dash3d.templates' is explicitly added
#         to the `packages` configuration field.
#
#         Alternatively, you can also rely on setuptools' discovery methods
#         (for example by using `find_namespace_packages(...)`/`find_namespace:`
#         instead of `find_packages(...)`/`find:`).
#
#         You can read more about "package discovery" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#         If you don't want 'kaolin.experimental.dash3d.templates' to be distributed and are
#         already explicitly excluding 'kaolin.experimental.dash3d.templates' via
#         `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#         you can try to use `exclude_package_data`, or `include-package-data=False` in
#         combination with a more fine grained `package-data` configuration.
#
#         You can read more about "package data files" on setuptools documentation page:
#
#         - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#         [^1]: For Python, any directory (with suitable naming) can be imported,
#               even if it does not contain any `.py` files.
#               On the other hand, currently there is no concept of package data
#               directory, all directories are treated like packages.
#         ********************************************************************************
#
# !!
#   check.warn(importable)
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/csrc
# INFO - copying kaolin/csrc/bindings.cpp -> build/lib.linux-x86_64-cpython-312/kaolin/csrc
# INFO - creating build/lib.linux-x86_64-cpython-312/kaolin/csrc/metrics
# ...
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/angle_axis.py to angle_axis.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/util.py to util.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/quaternion.py to quaternion.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/math/quat/euclidean.py to euclidean.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/reduction.py to reduction.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/trianglemesh.py to trianglemesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/mesh.py to mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/check_sign.py to check_sign.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/mesh/tetmesh.py to tetmesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/convolution.py to convolution.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/uint8.py to uint8.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/raytraced_spc_dataset.py to raytraced_spc_dataset.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/spc.py to spc.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/bf_recon.py to bf_recon.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/spc/points.py to points.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/random.py to random.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/batch.py to batch.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/gcn.py to gcn.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/trianglemesh.py to trianglemesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/pointcloud.py to pointcloud.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/flexicubes/tables.py to tables.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/flexicubes/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/flexicubes/flexicubes.py to flexicubes.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/gaussians.py to gaussians.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/voxelgrid.py to voxelgrid.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/tetmesh.py to tetmesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/sdf.py to sdf.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/pointcloud.py to pointcloud.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/voxelgrid.py to voxelgrid.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/gaussian/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/gaussian/densifier.py to densifier.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/coords.py to coords.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/materials.py to materials.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/obj.py to obj.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/utils.py to utils.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/mesh.py to mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/off.py to off.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/gltf.py to gltf.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/shapenet.py to shapenet.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/materials.py to materials.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/utils.py to utils.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/pointcloud.py to pointcloud.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/mesh.py to mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/usd/voxelgrid.py to voxelgrid.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/modelnet.py to modelnet.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/render.py to render.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/shrec.py to shrec.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/io/dataset.py to dataset.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/version.py to version.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/common/collisions.py to collisions.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/common/scene_forces.py to scene_forces.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/common/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/common/optimization.py to optimization.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/skinning.py to skinning.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/losses_warp.py to losses_warp.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/precomputed.py to precomputed.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/losses.py to losses.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/easy_api.py to easy_api.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/simplicits/network.py to network.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/utils/finite_diff.py to finite_diff.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/utils/warp_utilities.py to warp_utilities.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/utils/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/utils/torch_utilities.py to torch_utilities.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/materials/linear_elastic_material.py to linear_elastic_material.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/materials/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/materials/material_utils.py to material_utils.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/physics/materials/neohookean_elastic_material.py to neohookean_elastic_material.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/materials.py to materials.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/rasterization.py to rasterization.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/deftet.py to deftet.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/utils.py to utils.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/nvdiffrast_context.py to nvdiffrast_context.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/mesh/dibr.py to dibr.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/spc/raytrace.py to raytrace.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/spc/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/intrinsics_pinhole.py to intrinsics_pinhole.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/legacy.py to legacy.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/coordinates.py to coordinates.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/extrinsics_backends.py to extrinsics_backends.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/polyscope.py to polyscope.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/gsplats.py to gsplats.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/camera.py to camera.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/trajectory.py to trajectory.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/intrinsics_ortho.py to intrinsics_ortho.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/raygen.py to raygen.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/intrinsics.py to intrinsics.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/camera/extrinsics.py to extrinsics.cpython-312.pyc
# build/bdist.linux-x86_64/egg/kaolin/render/camera/extrinsics.py:192: SyntaxWarning: invalid escape sequence '\:'
#   Values supported by default\: ``matrix_se3``, ``matrix_6dof_rotation`` (see class description).
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/lighting/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/lighting/sh.py to sh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/lighting/sg.py to sg.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/easy_render/common.py to common.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/easy_render/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/render/easy_render/mesh.py to mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/utils/testing.py to testing.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/utils/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/rep/surface_mesh.py to surface_mesh.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/rep/spc.py to spc.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/rep/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/visualize/__init__.py to __init__.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/visualize/ipython.py to ipython.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/visualize/timelapse.py to timelapse.cpython-312.pyc
# INFO - creating stub loader for kaolin/_C.so
# INFO - creating stub loader for kaolin/ops/conversions/mise.so
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/_C.py to _C.cpython-312.pyc
# INFO - byte-compiling build/bdist.linux-x86_64/egg/kaolin/ops/conversions/mise.py to mise.cpython-312.pyc
# INFO - creating build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - installing scripts to build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# INFO - running install_scripts
# INFO - running build_scripts
# INFO - creating build/scripts-3.12
# INFO - copying and adjusting kaolin/experimental/dash3d/kaolin-dash3d -> build/scripts-3.12
# INFO - changing mode of build/scripts-3.12/kaolin-dash3d from 644 to 755
# INFO - creating build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# INFO - copying build/scripts-3.12/kaolin-dash3d -> build/bdist.linux-x86_64/egg/EGG-INFO/scripts
# INFO - changing mode of build/bdist.linux-x86_64/egg/EGG-INFO/scripts/kaolin-dash3d to 755
# INFO - copying kaolin.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - copying kaolin.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# INFO - writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# INFO - creating 'dist/kaolin-0.18.0-py3.12-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# INFO - removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# INFO - Processing kaolin-0.18.0-py3.12-linux-x86_64.egg
# INFO - removing '/usr/local/lib/python3.12/dist-packages/kaolin-0.18.0-py3.12-linux-x86_64.egg' (and everything under it)
# INFO - creating /usr/local/lib/python3.12/dist-packages/kaolin-0.18.0-py3.12-linux-x86_64.egg
# INFO - Extracting kaolin-0.18.0-py3.12-linux-x86_64.egg to /usr/local/lib/python3.12/dist-packages
# /usr/local/lib/python3.12/dist-packages/kaolin-0.18.0-py3.12-linux-x86_64.egg/kaolin/render/camera/extrinsics.py:192: SyntaxWarning: invalid escape sequence '\:'
#   Values supported by default\: ``matrix_se3``, ``matrix_6dof_rotation`` (see class description).
# INFO - Adding kaolin 0.18.0 to easy-install.pth file
# INFO - Installing kaolin-dash3d script to /usr/local/bin
# INFO -
# Installed /usr/local/lib/python3.12/dist-packages/kaolin-0.18.0-py3.12-linux-x86_64.egg
# INFO - Processing dependencies for kaolin==0.18.0
# INFO - Searching for warp-lang
# INFO - Reading https://pypi.org/simple/warp-lang/
# INFO - Downloading https://files.pythonhosted.org/packages/dc/df/8849e44300d805096f94978a8e92fa48f4e79ebafb45042d3a68f9b3fd94/warp_lang-1.11.0.dev20251030.tar.gz#sha256=655d47582974849b90063416938c3019898d08d654c07335da3c1d143922fb1d
# INFO - Best match: warp-lang 1.11.0.dev20251030
# INFO - Processing warp_lang-1.11.0.dev20251030.tar.gz
# error: Couldn't find a setup script in /tmp/easy_install-x7c3qp_x/warp_lang-1.11.0.dev20251030.tar.gz
# /content/GazeGaussian
# ✓ Kaolin reinstalled from source

# %% [markdown]
# ## 4. Verify Installation

# %%
print("\n" + "="*80)
print("VERIFICATION")
print("="*80)

all_good = True

packages = [
    ('torch', 'PyTorch'),
    ('cv2', 'OpenCV'),
    ('h5py', 'h5py'),
    ('lpips', 'LPIPS'),
    ('kornia', 'Kornia'),
]

for mod, name in packages:
    try:
        m = __import__(mod)
        v = getattr(m, '__version__', 'OK')
        print(f"✓ {name:15s} {v}")
    except ImportError as e:
        print(f"✗ {name:15s} FAILED: {str(e)[:50]}")
        all_good = False

try:
    import simple_knn
    print(f"✓ {'simple-knn':15s} OK")
except ImportError as e:
    print(f"✗ {'simple-knn':15s} FAILED: {str(e)[:50]}")
    all_good = False

try:
    import diff_gaussian_rasterization
    print(f"✓ {'diff-gauss':15s} OK")
except ImportError as e:
    print(f"✗ {'diff-gauss':15s} FAILED: {str(e)[:50]}")
    all_good = False

try:
    import kaolin
    try:
        kaolin_version = kaolin.__version__
    except AttributeError:
        kaolin_version = 'OK (version unknown)'
    print(f"✓ {'kaolin':15s} {kaolin_version}")
except ImportError as e:
    print(f"✗ {'kaolin':15s} FAILED: {str(e)[:50]}")
    all_good = False

print("="*80)

if all_good:
    print("\n✅ ALL REQUIRED PACKAGES INSTALLED SUCCESSFULLY!")
    print("   Ready for training!")
else:
    print("\n⚠ Some packages failed. Check errors above and rerun failed installations.")

# %%
import os
os.environ['MAX_JOBS'] = '2'
os.environ['TORCH_CUDA_ARCH_LIST'] = '7.5;8.0;8.6'

# %cd submodules/diff-gaussian-rasterization
# !python setup.py install
# %cd ../..

# %%
import os
os.chdir('/content/GazeGaussian/submodules/simple-knn')
with open('simple_knn.cu', 'r') as f:
    content = f.read()
if '#include <cfloat>' not in content:
    content = content.replace('#include <vector>', '#include <vector>\n#include <cfloat>')
    with open('simple_knn.cu', 'w') as f:
        f.write(content)
os.chdir('/content/GazeGaussian')

# %cd submodules/simple-knn
# !python setup.py install
# %cd ../..

# %%
import os
os.environ['MAX_JOBS'] = '2'
os.environ['TORCH_CUDA_ARCH_LIST'] = '7.5;8.0;8.6'

# %cd submodules/diff-gaussian-rasterization
# !python setup.py install
# %cd ../..

# %% [markdown]
# ## 5. Configure Dataset

# %%
# %cd /content/GazeGaussian
# !rm -rf data
# !mkdir -p data
print("Cleaned and recreated data directory.")

# %%
# %cd /content/GazeGaussian

# !mkdir -p data
# %cd data

# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partaa
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partab
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partac
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partad
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partae
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partaf
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partag
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partah
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partai
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partaj
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partak
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partal
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partam
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/ETH-XGaze.zip.partan

# !cat ETH-XGaze.zip.part* > ETH-XGaze.zip && echo "Concatenation complete"
# !unzip ETH-XGaze.zip

# %cd /content/GazeGaussian/configs
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/config_models.zip
# !unzip config_models.zip

# %cd /content/GazeGaussian
# !mkdir -p checkpoint
# %cd checkpoint
# !wget https://huggingface.co/ucwxb/GazeGaussian/resolve/main/gazegaussian_ckp.pth

# %cd /content/GazeGaussian

# %%
import shutil
import os

print("Copying data to Google Drive (this takes time but saves redownloading)...")
os.makedirs('/content/drive/MyDrive/GazeGaussian_data', exist_ok=True)

if os.path.exists('/content/GazeGaussian/data/ETH-XGaze'):
    shutil.copytree('/content/GazeGaussian/data/ETH-XGaze',
                    '/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze',
                    dirs_exist_ok=True)
    print("✓ Training data saved to Drive")

if os.path.exists('/content/GazeGaussian/data/ETH-XGaze_test'):
    shutil.copytree('/content/GazeGaussian/data/ETH-XGaze_test',
                    '/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze_test',
                    dirs_exist_ok=True)
    print("✓ Test data saved to Drive")

if os.path.exists('/content/GazeGaussian/configs/config_models'):
    shutil.copytree('/content/GazeGaussian/configs/config_models',
                    '/content/drive/MyDrive/GazeGaussian_data/config_models',
                    dirs_exist_ok=True)
    print("✓ Config models saved to Drive")

# %%
import os

os.makedirs('/content/GazeGaussian/data', exist_ok=True)
os.makedirs('/content/GazeGaussian/configs', exist_ok=True)

if os.path.exists('/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze'):
    # !ln -s /content/drive/MyDrive/GazeGaussian_data/ETH-XGaze /content/GazeGaussian/data/ETH-XGaze
    print("✓ Linked training data from Drive")

if os.path.exists('/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze_test'):
    # !ln -s /content/drive/MyDrive/GazeGaussian_data/ETH-XGaze_test /content/GazeGaussian/data/ETH-XGaze_test
    print("✓ Linked test data from Drive")

if os.path.exists('/content/drive/MyDrive/GazeGaussian_data/config_models'):
    # !ln -s /content/drive/MyDrive/GazeGaussian_data/config_models /content/GazeGaussian/configs/config_models
    print("✓ Linked config models from Drive")

# %%
import os

print("\n" + "="*80)
print("DATA VERIFICATION")
print("="*80)

all_data_present = True

# Check for training data directory and a sample file
# Adjusted path and filename format based on actual extraction
train_data_path = '/content/GazeGaussian/data/ETH-XGaze'
sample_train_file = os.path.join(train_data_path, 'xgaze_subject0000.h5')
if os.path.exists(train_data_path) and os.path.exists(sample_train_file):
    print(f"✓ Training data directory and sample file found: {sample_train_file}")
    # Optional: check for number of files to be more robust
    # expected_num_files = 114 # Based on original description
    # if len(os.listdir(train_data_path)) >= expected_num_files:
    #     print(f"✓ Found at least {expected_num_files} training data files.")
    # else:
    #     print(f"⚠ Expected number of training files not found. Found {len(os.listdir(train_data_path))}")
    #     all_data_present = False
else:
    print(f"✗ Training data not found or incomplete. Expected: {sample_train_file}")
    all_data_present = False

# Check for config models directory
config_models_path = '/content/GazeGaussian/configs/config_models'
if os.path.exists(config_models_path):
    print(f"✓ Config models directory found: {config_models_path}")
else:
    print(f"✗ Config models not found. Expected: {config_models_path}")
    all_data_present = False

# Check for checkpoint file
checkpoint_path = '/content/GazeGaussian/checkpoint/gazegaussian_ckp.pth'
if os.path.exists(checkpoint_path):
    print(f"✓ Checkpoint file found: {checkpoint_path}")
else:
    print(f"✗ Checkpoint file not found. Expected: {checkpoint_path}")
    all_data_present = False

print("="*80)

if all_data_present:
    print("\n✅ All necessary data appears to be present. Ready to proceed with training.")
else:
    print("\n⚠ Some necessary data is missing. Please ensure all download and extraction steps were successful.")

# %%
import shutil
import os

print("Copying data to Google Drive (this takes time but saves redownloading)...")
os.makedirs('/content/drive/MyDrive/GazeGaussian_data', exist_ok=True)

# Copy the ETH-XGaze_test data
test_data_src = '/content/GazeGaussian/data/ETH-XGaze_test'
test_data_dest = '/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze_test'
if os.path.exists(test_data_src):
    shutil.copytree(test_data_src, test_data_dest, dirs_exist_ok=True)
    print("✓ Test data saved to Drive")
else:
    print("✗ Test data not found at source")

# Copy the config models
config_models_src = '/content/GazeGaussian/configs/config_models'
config_models_dest = '/content/drive/MyDrive/GazeGaussian_data/config_models'
if os.path.exists(config_models_src):
    shutil.copytree(config_models_src, config_models_dest, dirs_exist_ok=True)
    print("✓ Config models saved to Drive")
else:
    print("✗ Config models not found at source")


# Copy the checkpoint file
checkpoint_src = '/content/GazeGaussian/checkpoint/gazegaussian_ckp.pth'
checkpoint_dest_dir = '/content/drive/MyDrive/GazeGaussian_checkpoints'
checkpoint_dest_file = os.path.join(checkpoint_dest_dir, 'gazegaussian_ckp.pth')
if os.path.exists(checkpoint_src):
    os.makedirs(checkpoint_dest_dir, exist_ok=True)
    shutil.copy(checkpoint_src, checkpoint_dest_file)
    print("✓ Checkpoint file saved to Drive")
else:
    print("✗ Checkpoint file not found at source")

# %%
import os

os.makedirs('/content/GazeGaussian/data', exist_ok=True)
os.makedirs('/content/GazeGaussian/configs', exist_ok=True)
os.makedirs('/content/GazeGaussian/checkpoint', exist_ok=True)

# Link the ETH-XGaze_test data
test_data_src = '/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze_test'
test_data_dest = '/content/GazeGaussian/data/ETH-XGaze_test'
if os.path.exists(test_data_src) and not os.path.exists(test_data_dest):
    # !ln -s {test_data_src} {test_data_dest}
    print("✓ Linked test data from Drive")
elif os.path.exists(test_data_dest):
    print("✓ Test data directory already exists")
else:
    print("✗ Test data not found in Drive to link")


# Link the config models
config_models_src = '/content/drive/MyDrive/GazeGaussian_data/config_models'
config_models_dest = '/content/GazeGaussian/configs/config_models'
if os.path.exists(config_models_src) and not os.path.exists(config_models_dest):
    # !ln -s {config_models_src} {config_models_dest}
    print("✓ Linked config models from Drive")
elif os.path.exists(config_models_dest):
    print("✓ Config models directory already exists")
else:
    print("✗ Config models not found in Drive to link")

# Link the checkpoint file
checkpoint_src = '/content/drive/MyDrive/GazeGaussian_checkpoints/gazegaussian_ckp.pth'
checkpoint_dest = '/content/GazeGaussian/checkpoint/gazegaussian_ckp.pth'
if os.path.exists(checkpoint_src) and not os.path.exists(checkpoint_dest):
    # !ln -s {checkpoint_src} {checkpoint_dest}
    print("✓ Linked checkpoint file from Drive")
elif os.path.exists(checkpoint_dest):
    print("✓ Checkpoint file already exists")
else:
     print("✗ Checkpoint file not found in Drive to link")

# Link the ETH-XGaze training data if it exists in Drive
train_data_src = '/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze'
train_data_dest = '/content/GazeGaussian/data/ETH-XGaze'
if os.path.exists(train_data_src) and not os.path.exists(train_data_dest):
    # !ln -s {train_data_src} {train_data_dest}
    print("✓ Linked training data from Drive")
elif os.path.exists(train_data_dest):
    print("✓ Training data directory already exists")
else:
    print("✗ Training data not found in Drive to link")

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# ## 6. STEP 1: Train MeshHead (~10 epochs, ~2-3 hours)
#
# This creates the canonical 3D head model.

# %%
# !pip install pygltflib

# %%
# %cd /content/GazeGaussian

# !python train_meshhead.py \
    --batch_size 1 \
    --name 'meshhead' \
    --img_dir '/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze/train' \
    --num_epochs 10 \
    --num_workers 2 \
    --early_stopping \
    --patience 5 \
    --dataset_name 'eth_xgaze'

# %% [markdown]
# ## 7. Verify MeshHead Checkpoint

# %%
import glob
import os

checkpoints = glob.glob("/content/GazeGaussian/work_dirs/meshhead_*/checkpoints/*.pth")
if checkpoints:
    latest_checkpoint = sorted(checkpoints)[-1]
    print(f"✓ MeshHead checkpoint found: {latest_checkpoint}")
    print(f"  Size: {os.path.getsize(latest_checkpoint) / (1024**2):.2f} MB")

    with open('/content/meshhead_checkpoint.txt', 'w') as f:
        f.write(latest_checkpoint)
    print(f"\n✓ Checkpoint path saved for Step 2")
else:
    print("❌ No MeshHead checkpoint found! Training may have failed.")

# %% [markdown]
# ## 8. Verify DiT Configuration

# %%
from configs.gazegaussian_options import BaseOptions

opt = BaseOptions()

print("="*80)
print("ENHANCED MODEL CONFIGURATION")
print("="*80)
print(f"\n✓ Neural Renderer Type: {opt.neural_renderer_type}")
print(f"✓ DiT Depth: {opt.dit_depth}")
print(f"✓ DiT Num Heads: {opt.dit_num_heads}")
print(f"✓ DiT Patch Size: {opt.dit_patch_size}")
print(f"✓ VAE Enabled: {opt.use_vae}")
print(f"✓ VAE Z Channels: {opt.vae_z_channels}")
print(f"✓ VAE Frozen: {opt.freeze_vae}")
print(f"✓ Orthogonality Loss: {opt.use_orthogonality_loss}")
print(f"✓ Orthogonality Importance: {opt.orthogonality_loss_importance}")

if opt.neural_renderer_type == "dit" and opt.use_vae and opt.use_orthogonality_loss:
    print("\n✅ All 3 enhancements are ACTIVE!")
else:
    print("\n⚠ Some enhancements may be disabled!")

# %% [markdown]
# ## 9. STEP 2: Train GazeGaussian with DiT (~30 epochs, ~8-12 hours)
#
# This trains the full pipeline with your 3 enhancements.

# %%
# %cd /content/GazeGaussian

# Corrected: Reading the MeshHead checkpoint path from the text file
with open('/content/meshhead_checkpoint.txt', 'r') as f:
    meshhead_checkpoint = f.read().strip()

print(f"Loading MeshHead from: {meshhead_checkpoint}")

# !python train_gazegaussian.py \
    --batch_size 1 \
    --name 'gazegaussian_dit' \
    --img_dir '/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze/train' \
    --num_epochs 30 \
    --num_workers 2 \
    --lr 0.0001 \
    --clip_grad \
    --load_meshhead_checkpoint {meshhead_checkpoint} \
    --dataset_name 'eth_xgaze'

# %% [markdown]
# ## 10. Verify Final Checkpoint

# %% [markdown]
# ## 11. Generate Test Samples
#
# Generate a few redirected gaze/pose samples for verification.

# %%
# TODO: Add inference code to generate samples
# This will be added after confirming training works
# print("Sample generation coming in next update...")

import os

# Define the path to the checkpoint in Google Drive
checkpoint_path = '/content/drive/MyDrive/GazeGaussian_checkpoints/gazegaussian_ckp.pth'

# Define the output directory for generated samples
output_dir = '/content/GazeGaussian/generated_samples'
os.makedirs(output_dir, exist_ok=True)

# Change to the GazeGaussian directory
# %cd /content/GazeGaussian

# Run the inference script
# You might need to adjust the command based on the actual inference script and its arguments
# This is a placeholder command, replace with the correct one from the GazeGaussian project
print(f"Generating samples using checkpoint: {checkpoint_path}")
# !python generate_samples.py \
    --checkpoint_path {checkpoint_path} \
    --output_dir {output_dir} \
    --dataset_name 'eth_xgaze' # Or the appropriate dataset name for inference

# %%
import os

checkpoint_dir = '/content/drive/MyDrive/GazeGaussian_checkpoints'

print(f"Checking for checkpoints in: {checkpoint_dir}")

if os.path.exists(checkpoint_dir):
    checkpoints = [f for f in os.listdir(checkpoint_dir) if f.endswith('.pth')]
    if checkpoints:
        print("\nFound the following checkpoints:")
        for ckp in checkpoints:
            print(f"- {ckp}")
    else:
        print("\nNo .pth checkpoint files found in the directory.")
else:
    print("\nCheckpoint directory not found in Google Drive.")

# %%
# ============================================================================
# GAZEGAUSSIAN CHECKPOINT TESTING - SINGLE CELL
# ============================================================================

import torch
import os
from pathlib import Path
import numpy as np
from PIL import Image
import torchvision.utils as vutils
from tqdm import tqdm
from IPython.display import display, Image as IPImage

# %cd /content/GazeGaussian

# %% [markdown]
# Testing chckpoints

# %%
# ============================================================================
# GAZEGAUSSIAN CHECKPOINT TESTING - SINGLE CELL
# ============================================================================

import torch
import os
from pathlib import Path
import numpy as np
from PIL import Image
import torchvision.utils as vutils
from tqdm import tqdm
from IPython.display import display, Image as IPImage

# %cd /content/GazeGaussian

from configs.gazegaussian_options import BaseOptions
from models.gaze_gaussian import GazeGaussianNet
from dataloader.eth_xgaze import get_val_loader

def save_image_grid(images, save_path, nrow=4):
    """Save a grid of images"""
    grid = vutils.make_grid(images, nrow=nrow, normalize=True, value_range=(-1, 1))
    grid_np = grid.cpu().numpy().transpose(1, 2, 0)
    grid_np = np.clip((grid_np * 0.5 + 0.5) * 255, 0, 255).astype(np.uint8)
    Image.fromarray(grid_np).save(save_path)
    return grid_np

# ============================================================================
# CONFIGURE YOUR PATHS HERE
# ============================================================================
checkpoint_path = "/content/drive/MyDrive/GazeGaussian_checkpoints/gazegaussian_ckp.pth"
data_dir = "/content/drive/MyDrive/GazeGaussian_data/ETH-XGaze_test/ETH-XGaze_test"
output_dir = "/content/test_outputs"
num_samples = 10  # Change this to generate more/fewer samples
device = 'cuda'
# ============================================================================

print("=" * 80)
print("GAZEGAUSSIAN CHECKPOINT TESTING")
print("=" * 80)

os.makedirs(output_dir, exist_ok=True)

# 1. Load checkpoint
print(f"\n[1/5] Loading checkpoint...")
if not os.path.exists(checkpoint_path):
    print(f"✗ Checkpoint not found: {checkpoint_path}")
    raise FileNotFoundError(checkpoint_path)

checkpoint = torch.load(checkpoint_path, map_location=device)
print(f"✓ Checkpoint loaded")

if isinstance(checkpoint, dict) and 'epoch' in checkpoint:
    print(f"  - Epoch: {checkpoint['epoch']}")
if isinstance(checkpoint, dict) and 'loss' in checkpoint:
    print(f"  - Loss: {checkpoint['loss']:.4f}")

# 2. Initialize model
print(f"\n[2/5] Initializing model...")
opt = BaseOptions()

if isinstance(checkpoint, dict) and 'model_state_dict' in checkpoint:
    state_dict = checkpoint['model_state_dict']
elif isinstance(checkpoint, dict):
    state_dict = checkpoint
else:
    state_dict = None

model = GazeGaussianNet(opt, load_state_dict=state_dict)
model = model.to(device)
model.eval()
print("✓ Model initialized")

if hasattr(model, 'neural_render'):
    renderer_type = type(model.neural_render).__name__
    print(f"  - Neural Renderer: {renderer_type}")

# 3. Load validation data
print(f"\n[3/5] Loading validation data...")
opt.img_dir = data_dir
val_loader = get_val_loader(
    opt,
    data_dir=data_dir,
    batch_size=1,
    num_workers=0,
    evaluate=None,
    dataset_name='eth_xgaze'
)
print(f"✓ Data loaded ({len(val_loader.dataset)} samples)")

# 4. Generate images
print(f"\n[4/5] Generating {num_samples} images...")

success_count = 0

with torch.no_grad():
    for idx, data in enumerate(tqdm(val_loader, total=min(num_samples, len(val_loader)), desc="Generating")):
        if idx >= num_samples:
            break

        try:
            # Move data to device
            for key in data:
                if isinstance(data[key], torch.Tensor):
                    data[key] = data[key].to(device)
                elif isinstance(data[key], dict):
                    for sub_key in data[key]:
                        if isinstance(data[key][sub_key], torch.Tensor):
                            data[key][sub_key] = data[key][sub_key].to(device)

            # Forward pass
            output = model(data)

            # Get images
            gt_image = data.get('image', None)
            if gt_image is None:
                gt_image = data.get('img', None)

            # Get rendered images
            gaussian_img = output['total_render_dict']['merge_img']
            neural_img = output['total_render_dict']['merge_img_pro']

            # Create comparison
            if gt_image is not None:
                comparison = torch.cat([gt_image, gaussian_img, neural_img], dim=0)
            else:
                comparison = torch.cat([gaussian_img, neural_img], dim=0)

            # Save images
            save_path = os.path.join(output_dir, f"test_sample_{idx:03d}.png")
            save_image_grid(comparison, save_path, nrow=len(comparison))
            save_image_grid(gaussian_img, os.path.join(output_dir, f"test_sample_{idx:03d}_gaussian.png"), nrow=1)
            save_image_grid(neural_img, os.path.join(output_dir, f"test_sample_{idx:03d}_dit.png"), nrow=1)

            success_count += 1

        except Exception as e:
            print(f"\n✗ Error on sample {idx}: {e}")
            continue

# 5. Summary
print(f"\n[5/5] Summary")
print("=" * 80)
print(f"✅ Successfully generated {success_count}/{num_samples} images")
print(f"   Output: {output_dir}")
print("=" * 80)

# Copy to Drive
# !cp -r {output_dir} /content/drive/MyDrive/gazegaussian_test_outputs
print(f"✓ Saved to Drive: /content/drive/MyDrive/gazegaussian_test_outputs")

# Display first 5 samples
print(f"\n{'='*80}\nDISPLAYING RESULTS\n{'='*80}")
for i in range(min(5, success_count)):
    img_path = os.path.join(output_dir, f"test_sample_{i:03d}.png")
    if os.path.exists(img_path):
        print(f"\n--- Sample {i} ---")
        display(IPImage(filename=img_path))

print(f"\n{'='*80}\n✅ TESTING COMPLETE!\n{'='*80}")

# %%
import os
os.environ['IGNORE_TORCH_VER'] = '1'
os.environ['FORCE_CUDA'] = '1'

# %cd /content/kaolin
# !python setup.py clean --all
# !python setup.py install
# %cd /content/GazeGaussian
print("✓ Kaolin reinstalled from source")

# %%
import os
os.environ['IGNORE_TORCH_VER'] = '1'
os.environ['FORCE_CUDA'] = '1'

# %cd /content/kaolin
# !python setup.py clean --all
# !python setup.py install
# %cd /content/GazeGaussian
print("✓ Kaolin reinstalled from source")

# %%
print("\n" + "="*80)
print("VERIFICATION")
print("="*80)

all_good = True

packages = [
    ('torch', 'PyTorch'),
    ('cv2', 'OpenCV'),
    ('h5py', 'h5py'),
    ('lpips', 'LPIPS'),
    ('kornia', 'Kornia'),
]

for mod, name in packages:
    try:
        m = __import__(mod)
        v = getattr(m, '__version__', 'OK')
        print(f"✓ {name:15s} {v}")
    except ImportError as e:
        print(f"✗ {name:15s} FAILED: {str(e)[:50]}")
        all_good = False

try:
    import simple_knn
    print(f"✓ {'simple-knn':15s} OK")
except ImportError as e:
    print(f"✗ {'simple-knn':15s} FAILED: {str(e)[:50]}")
    all_good = False

try:
    import diff_gaussian_rasterization
    print(f"✓ {'diff-gauss':15s} OK")
except ImportError as e:
    print(f"✗ {'diff-gauss':15s} FAILED: {str(e)[:50]}")
    all_good = False

try:
    import kaolin
    try:
        kaolin_version = kaolin.__version__
    except AttributeError:
        kaolin_version = 'OK (version unknown)'
    print(f"✓ {'kaolin':15s} {kaolin_version}")
except ImportError as e:
    print(f"✗ {'kaolin':15s} FAILED: {str(e)[:50]}")
    all_good = False

print("="*80)

if all_good:
    print("\n✅ ALL REQUIRED PACKAGES INSTALLED SUCCESSFULLY!")
    print("   Ready for training!")
else:
    print("\n⚠ Some packages failed. Check errors above and rerun failed installations.")
